# %% [markdown]
# **Store and Print the Absolute Value**

# %%
number = -25

absolute_value = abs(number)

print("Original number :", number)
print("Absolute value :", absolute_value)
# Out:
# Original number : -25
# Absolute value : 25

# %% [markdown]
# **Positive Number example**

# %%
number = 15

print(abs(number))
# Out:
# 15

# %% [markdown]
# **Negative Number example**

# %%
number = 50

print(abs(number))
# Out:
# 50

# %% [markdown]
# **Float Example**

# %%
number = -12.75

absolute_value = abs(number)

print(absolute_value)
# Out:
# 12.75

# %% [markdown]
# **User Input Example**

# %%
number = float(input("Enter a number: "))

absolute_value = abs(number)

print("Absolute_value:", absolute_value)
# Out:
# Enter a number:  -2345256436
# Absolute_value: 2345256436.0
