# %% [markdown]
# **Check Types of Different Variable**

# %%
name = "John"
age = 25
height = 5.8
is_student = True
skills = ["Python", "SQL", "AI"]
address = {"city": "Bangalore"}

print("name: ", type(name))
print("age: ", type(age))
print("height :", type(height))
print("is_student :", type(is_student))
print("skill :", type(skills))
print("address :", type(address))
# Out:
# name:  <class 'str'>
# age:  <class 'int'>
# height : <class 'float'>
# is_student : <class 'bool'>
# skill : <class 'list'>
# address : <class 'dict'>

# %% [markdown]
# **Using a Profile Example**

# %%
profile = {
    "name": "John",
    "age": 25,
    "height": 5.8,
    "is_student": True,
    "skills": ["Python", "Machine Learning"]
}

for key, value in profile.items():
    print(key, "=", value, "->", type(value))
# Out:
# name = John -> <class 'str'>
# age = 25 -> <class 'int'>
# height = 5.8 -> <class 'float'>
# is_student = True -> <class 'bool'>
# skills = ['Python', 'Machine Learning'] -> <class 'list'>
